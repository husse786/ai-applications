# %%
# TODO Create an google api key and add it here
# TODO add the OPEN_AI_KEY from moodle
GOOGLE_API_KEY = ''
OPEN_AI_KEY = ''

# %%
import requests

ADDRESS = "Greifenseestr. 53, 8050 Zürich"

# Convert address to URL format
address_url = ADDRESS.replace(" ", "+")

# Get latitude and longitude using Geocoding API
geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address_url}&key={GOOGLE_API_KEY}"
geo_response = requests.get(geocode_url).json()

if geo_response["status"] == "OK":
    location = geo_response["results"][0]["geometry"]["location"]
    lat, lon = location["lat"], location["lng"]

    # Angles to capture (90° = East, 180° = South, 270° = West)
    headings = [0, 90, 180, 270]  # 0° (North), 90° (East), 180° (South), 270° (West)

    for heading in headings:
        streetview_url = (
            f"https://maps.googleapis.com/maps/api/streetview?size=600x400&location={lat},{lon}"
            f"&heading={heading}&fov=80&key={GOOGLE_API_KEY}"
        )

        response = requests.get(streetview_url)

        if response.status_code == 200:
            filename = f"streetview_{heading}.jpg"
            with open(filename, "wb") as file:
                file.write(response.content)
            print(f"Street View image saved: {filename}")
        else:
            print(f"Error fetching the {heading}° Street View image:", response.status_code)
else:
    print("Error getting coordinates:", geo_response["status"])
# Out:
# {'results': [{'address_components': [{'long_name': '53', 'short_name': '53', 'types': ['street_number']}, {'long_name': 'Greifenseestrasse', 'short_name': 'Greifenseestrasse', 'types': ['route']}, {'long_name': 'Zürich', 'short_name': 'Zürich', 'types': ['locality', 'political']}, {'long_name': 'Zürich', 'short_name': 'Zürich', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Zürich', 'short_name': 'ZH', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Switzerland', 'short_name': 'CH', 'types': ['country', 'political']}, {'long_name': '8050', 'short_name': '8050', 'types': ['postal_code']}], 'formatted_address': 'Greifenseestrasse 53, 8050 Zürich, Switzerland', 'geometry': {'location': {'lat': 47.40910239999999, 'lng': 8.5579001}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 47.41034638029149, 'lng': 8.559250930291501}, 'southwest': {'lat': 47.4076484197085, 'lng': 8.556552969708497}}}, 'navigation_points': [{'location': {'latitude': 47.4089554, 'longitude': 8.557902}}], 'place_id': 'ChIJsSE8uH6gmkcRK02Z6qsw4A8', 'types': ['street_address', 'subpremise']}], 'status': 'OK'}
# Street View image saved: streetview_0.jpg
# Street View image saved: streetview_90.jpg
# Street View image saved: streetview_180.jpg
# Street View image saved: streetview_270.jpg

# %%
import base64
from typing import Literal

from openai import OpenAI
from pydantic import BaseModel


class StreetViewAnalysis(BaseModel):
    road_size: str
    speed_limit: Literal[30, 50, 80]
    house_condition: str


client = OpenAI(api_key=OPEN_AI_KEY)


# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


# Path to your image
image_path = "streetview_0.jpg"
image_path_90 = "streetview_90.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)
base64_image_90 = encode_image(image_path_90)

prompt = (
    "Analyze the road size, predict the speed limit, and determine the house condition. "
    "Use the schema exactly: road_size as string, speed_limit as one of 30/50/80, "
    "and house_condition as string."
)

response = client.responses.parse(
    model="gpt-4o-mini-2024-07-18",
    input=[
        {
            "role": "user",
            "content": [
                {"type": "input_text", "text": prompt},
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image_90}",
                },
            ],
        }
    ],
    text_format=StreetViewAnalysis,
)

analysis = response.output_parsed
print(analysis.model_dump_json(indent=2))
# Out:
# {
#   "road_size": "narrow",
#   "speed_limit": 30,
#   "house_condition": "well-maintained"
# }
